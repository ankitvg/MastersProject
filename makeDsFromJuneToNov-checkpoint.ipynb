# %%
import pandas as pd
import numpy as np

# %%
dsFile = pd.read_csv('data_files/ds_dump_1.csv')

# %%
AMD_all = dsFile.loc[dsFile['ds_loc'] == "AMD"]

# %%
AMD_all.head()
# Out:
#           ds_clust                ds_name  ds_cap_gb  ds_free_space  \
# 1309896  amdc4e01p  AMD-5700-01_CL1STD_50    5119.75     416.253906
# 1309897  amdc4e01p  AMD-5700-01_CL1STD_50    5119.75     416.253906
# 1309898  amdc4e01p  AMD-5700-01_CL1STD_50    5119.75     416.253906
# 1309899  amdc4e01p  AMD-5700-01_CL1STD_50    5119.75     416.253906
# 1309900  amdc4e01p  AMD-5700-01_CL1STD_50    5119.75     416.253906
#
#         ds_storagetier ds_storagetype  ds_readiops  ds_writeiops ds_loc  \
# 1309896       STANDARD           VMFS          NaN           NaN    AMD
# 1309897       STANDARD           VMFS          NaN           NaN    AMD
# 1309898       STANDARD           VMFS          NaN           NaN    AMD
# 1309899       STANDARD           VMFS          NaN           NaN    AMD
# 1309900       STANDARD           VMFS          NaN           NaN    AMD
#
#                      ds_time  ds_provisionedgb  ds_overprovisionedgb
# ...

# %%
AMD_all.ds_clust.unique()
# Out:
# array(['amdc4e01p'], dtype=object)

# %%
AMD_all.ds_name.unique()
# Out:
# array(['AMD-5700-01_CL1STD_50', 'AMD-5700-01_CL1STD_51',
#        'AMD-5700-01_CL1STD_52', 'AMD-5700-01_CL1STD_53',
#        'AMD-5700-01_CL1STD_54', 'AMD-5700-01_CL1STD_55',
#        'AMD-5700-01_CL1STD_56', 'AMD-5700-01_CL1STD_57',
#        'AMD-5700-01_CL1STD_58', 'AMD-5700-01_CL1STD_59',
#        'AMD-5700-01_CL1STD_60', 'AMD-5700-01_CL1STD_61',
#        'AMD-5700-01_CL1STD_62', 'AMD-5700-01_CL1STD_63',
#        'AMD-5700-01_CL1STD_64', 'AMD-5700-01_CL1STD_65',
#        'AMD-5700-01_CL1STD_66', 'AMD-5700-01_CL1STD_67',
#        'AMD-5700-01_CL1STD_68', 'AMD-5700-01_CL1STD_69',
#        'AMD-5700-01_CL1STD_70', 'AMD-5700-01_CL1STD_71',
#        'AMD-5700-01_CL1STD_72', 'AMD-5700-01_CL1STD_73',
#        'AMD-5700-01_CL1STD_74', 'AMD-5700-01_CL1STD_75',
#        'AMD-5700-01_CL1STD_76', 'AMD-5700-01_CL1STD_77',
#        'AMD-5700-01_CL1STD_78', 'AMD-5700-01_CL1STD_79',
#        'AMD-5700-01_CL1STD_80', 'AMD_5700-01_CL1STD_36',
# ...

# %%
AMD_groupedByName = AMD_all.groupby('ds_name')

# %%
AMD_groupedByName.head()
# Out:
#            ds_clust                ds_name  ds_cap_gb  ds_free_space  \
# 1309896   amdc4e01p  AMD-5700-01_CL1STD_50    5119.75     416.253906
# 1309897   amdc4e01p  AMD-5700-01_CL1STD_50    5119.75     416.253906
# 1309898   amdc4e01p  AMD-5700-01_CL1STD_50    5119.75     416.253906
# 1309899   amdc4e01p  AMD-5700-01_CL1STD_50    5119.75     416.253906
# 1309900   amdc4e01p  AMD-5700-01_CL1STD_50    5119.75     416.253906
# 1333033   amdc4e01p  AMD-5700-01_CL1STD_51    5119.75      38.804688
# 1333034   amdc4e01p  AMD-5700-01_CL1STD_51    5119.75      38.804688
# 1333035   amdc4e01p  AMD-5700-01_CL1STD_51    5119.75      38.804688
# 1333036   amdc4e01p  AMD-5700-01_CL1STD_51    5119.75      38.804688
# 1333037   amdc4e01p  AMD-5700-01_CL1STD_51    5119.75      38.804688
# 1360931   amdc4e01p  AMD-5700-01_CL1STD_52    5119.75       1.533203
# 1360932   amdc4e01p  AMD-5700-01_CL1STD_52    5119.75       1.533203
# 1360933   amdc4e01p  AMD-5700-01_CL1STD_52    5119.75       1.533203
# ...

# %%
AMD_groupedByName.agg(['mean'])
# Out:
#                          ds_cap_gb ds_free_space ds_readiops ds_writeiops  \
#                               mean          mean        mean         mean
# ds_name
# AMD-5700-01_CL1STD_50  5119.750000   2847.658710         NaN          NaN
# AMD-5700-01_CL1STD_51  5119.750000   3079.113624         NaN          NaN
# AMD-5700-01_CL1STD_52  5119.750000   3004.022198         NaN          NaN
# AMD-5700-01_CL1STD_53  5119.750000   3166.757609         NaN          NaN
# AMD-5700-01_CL1STD_54  5119.750000   3431.427422         NaN          NaN
# AMD-5700-01_CL1STD_55  5119.750000   4990.719091         NaN          NaN
# AMD-5700-01_CL1STD_56  5119.750000   4938.434770         NaN          NaN
# AMD-5700-01_CL1STD_57  5119.750000   4766.214873         NaN          NaN
# AMD-5700-01_CL1STD_58  5119.750000   4862.662971         NaN          NaN
# AMD-5700-01_CL1STD_59  5119.750000   4990.719418         NaN          NaN
# ...

# %%
ds_jun2016_all = dsFile[dsFile.ds_time.str.contains('(06|07|08|09|10)\/[0-9]{1,2}\/2016') > 0]
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   if __name__ == '__main__':

# %%
ds_oct22016_all = dsFile[dsFile.ds_time.str.contains('2016-10') > 0]

# %%
ds_nov2016_all = dsFile[dsFile.ds_time.str.contains('2016-11') > 0]

# %%
ds_oct22016_all.head()
# Out:
#                       ds_clust                            ds_name  ds_cap_gb  \
# 29389495  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 29389496  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 29389497  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 29389498  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 29389499  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
#
#           ds_free_space   ds_storagetier ds_storagetype  ds_readiops  \
# 29389495      56.038086  HIGHPERFORMANCE           VMFS          NaN
# 29389496      56.038086  HIGHPERFORMANCE           VMFS          NaN
# 29389497      56.038086  HIGHPERFORMANCE           VMFS          NaN
# 29389498      56.038086  HIGHPERFORMANCE           VMFS          NaN
# 29389499      56.038086  HIGHPERFORMANCE           VMFS          NaN
#
#           ds_writeiops     ds_loc              ds_time  ds_provisionedgb  \
# ...

# %%
ds_6months = pd.DataFrame()

# %%
ds_6months.append(ds_jun2016_all).append(ds_oct22016_all).append(ds_nov2016_all)
# Out:
#                       ds_clust                            ds_name  ds_cap_gb  \
# 109       ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 110       ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 111       ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 112       ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 113       ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 114       ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 115       ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 116       ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 117       ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 118       ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 119       ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# ...

# %%
ds_6months.size
# Out:
# 0

# %%
ds_jun2016_all.size
# Out:
# 123363384

# %%
ds_oct22016_all.size
# Out:
# 11776200

# %%
ds_nov2016_all.size
# Out:
# 30481728

# %%
ds_jun2016_all.size+ds_oct22016_all.size+ds_nov2016_all.size
# Out:
# 165621312

# %%
ds1=ds_jun2016_all.append(ds_oct22016_all)

# %%
ds2=ds1.append(ds_nov2016_all)

# %%
ds_jun2016_all.size
# Out:
# 123363384

# %%
ds2.size
# Out:
# 165621312

# %%
ds_oct22016_all['Date'] = pd.to_datetime(ds_oct22016_all['ds_time'], yearfirst=True)
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ds_oct22016_all.size
# Out:
# 12757550

# %%
ds_oct22016_all.head()
# Out:
#                       ds_clust                            ds_name  ds_cap_gb  \
# 29389495  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 29389496  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 29389497  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 29389498  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 29389499  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
#
#           ds_free_space   ds_storagetier ds_storagetype  ds_readiops  \
# 29389495      56.038086  HIGHPERFORMANCE           VMFS          NaN
# 29389496      56.038086  HIGHPERFORMANCE           VMFS          NaN
# 29389497      56.038086  HIGHPERFORMANCE           VMFS          NaN
# 29389498      56.038086  HIGHPERFORMANCE           VMFS          NaN
# 29389499      56.038086  HIGHPERFORMANCE           VMFS          NaN
#
#           ds_writeiops     ds_loc              ds_time  ds_provisionedgb  \
# ...

# %%
ds_oct22016_all.isnull().sum()
# Out:
# ds_clust                     0
# ds_name                      0
# ds_cap_gb                    0
# ds_free_space                0
# ds_storagetier               0
# ds_storagetype               0
# ds_readiops             981350
# ds_writeiops            981350
# ds_loc                       0
# ds_time                      0
# ds_provisionedgb        976002
# ds_overprovisionedgb    976626
# Date                         0
# dtype: int64

# %%
ds_oct2016_2016_10 = dsFile[dsFile.ds_time.str.contains('2016-10') > 0]

# %%
ds_oct2016_2016_10.size
# Out:
# 11776200

# %%
ds_jun2016_all['Date'] = pd.to_datetime(ds_jun2016_all['ds_time'], format="%m/%d/%Y %H:%M:%S")
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ds_jun2016_all.size
# Out:
# 133643666

# %%
133643666 - 123363384
# Out:
# 10280282

# %%
ds_jun2016_all.isnull().sum()
# Out:
# ds_clust                       0
# ds_name                        0
# ds_cap_gb                      0
# ds_free_space                  0
# ds_storagetier                 0
# ds_storagetype                 0
# ds_readiops             10280282
# ds_writeiops            10280282
# ds_loc                         0
# ds_time                        0
# ds_provisionedgb        10280282
# ds_overprovisionedgb    10280282
# Date                           0
# dtype: int64

# %%
ds_jun2016_all = dsFile[dsFile.ds_time.str.contains('(06|07|08|09|10)\/[0-9]{1,2}\/2016') > 0]
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   if __name__ == '__main__':

# %%
ds_jun2016_all.dtypes
# Out:
# ds_clust                 object
# ds_name                  object
# ds_cap_gb               float64
# ds_free_space           float64
# ds_storagetier           object
# ds_storagetype           object
# ds_readiops             float64
# ds_writeiops            float64
# ds_loc                   object
# ds_time                  object
# ds_provisionedgb        float64
# ds_overprovisionedgb    float64
# dtype: object

# %%
ds_jun2016_all.drop(ds_jun2016_all.columns[[6,7,10,11]], axis=1, inplace=True)
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ds_jun2016_all.dtypes
# Out:
# ds_clust           object
# ds_name            object
# ds_cap_gb         float64
# ds_free_space     float64
# ds_storagetier     object
# ds_storagetype     object
# ds_loc             object
# ds_time            object
# dtype: object

# %%
ds_jun2016_all.size
# Out:
# 82242256

# %%
123363384-82242256
# Out:
# 41121128

# %%
ds_jun2016_all.isnull().sum()
# Out:
# ds_clust          0
# ds_name           0
# ds_cap_gb         0
# ds_free_space     0
# ds_storagetier    0
# ds_storagetype    0
# ds_loc            0
# ds_time           0
# dtype: int64

# %%
ds_jun2016_all.shape
# Out:
# (10280282, 8)

# %%
ds_jun2016_all['Date'] = pd.to_datetime(ds_jun2016_all['ds_time'], format="%m/%d/%Y %H:%M:%S")
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ds_jun2016_all.shape
# Out:
# (10280282, 9)

# %%
ds_jun2016_all.tail()
# Out:
#              ds_clust                ds_name  ds_cap_gb  ds_free_space  \
# 47001029  yyz01c4e01p  YYZ01_VNX-1-EC_VM_002    6143.75    6078.711914
# 47001030  yyz01c4e01p  YYZ01_VNX-1-EC_VM_002    6143.75    6078.711914
# 47001031  yyz01c4e01p  YYZ01_VNX-1-EC_VM_002    6143.75    6078.711914
# 47001032  yyz01c4e01p  YYZ01_VNX-1-EC_VM_002    6143.75    6078.711914
# 47001033  yyz01c4e01p  YYZ01_VNX-1-EC_VM_002    6143.75    6078.711914
#
#          ds_storagetier ds_storagetype ds_loc              ds_time  \
# 47001029        ECONOMY           VMFS  yyz01  09/19/2016 01:03:47
# 47001030        ECONOMY           VMFS  yyz01  09/19/2016 05:03:33
# 47001031        ECONOMY           VMFS  yyz01  09/19/2016 12:03:45
# 47001032        ECONOMY           VMFS  yyz01  09/19/2016 22:03:58
# 47001033        ECONOMY           VMFS  yyz01  09/20/2016 01:04:29
#
#                         Date
# 47001029 2016-09-19 01:03:47
# 47001030 2016-09-19 05:03:33
# 47001031 2016-09-19 12:03:45
# ...

# %%
ds_jun2016_all.drop(ds_jun2016_all.columns[[7]], axis=1, inplace=True)
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ds_jun2016_all.head()
# Out:
#                  ds_clust                            ds_name  ds_cap_gb  \
# 109  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 110  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 111  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 112  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 113  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
#
#      ds_free_space   ds_storagetier ds_storagetype     ds_loc  \
# 109      56.037109  HIGHPERFORMANCE           VMFS  ash02na15
# 110      56.037109  HIGHPERFORMANCE           VMFS  ash02na15
# 111      56.037109  HIGHPERFORMANCE           VMFS  ash02na15
# 112      56.037109  HIGHPERFORMANCE           VMFS  ash02na15
# 113      56.037109  HIGHPERFORMANCE           VMFS  ash02na15
#
#                    Date
# 109 2016-08-07 05:02:48
# 110 2016-08-07 07:02:54
# 111 2016-08-07 08:02:50
# 112 2016-08-07 09:02:50
# 113 2016-08-07 11:02:50

# %%
ds_oct22016_all = dsFile[dsFile.ds_time.str.contains('2016-10') > 0]

# %%
ds_nov2016_all = dsFile[dsFile.ds_time.str.contains('2016-11') > 0]

# %%
ds_oct22016_all.shape
# Out:
# (981350, 12)

# %%
ds_nov2016_all.shape
# Out:
# (2540144, 12)

# %%
ds_oct22016_all['Date'] = pd.to_datetime(ds_oct22016_all['ds_time'], yearfirst=True)
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ds_nov2016_all['Date'] = pd.to_datetime(ds_nov2016_all['ds_time'], yearfirst=True)
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ds_oct22016_all.shape
# Out:
# (981350, 13)

# %%
ds_nov2016_all.shape
# Out:
# (2540144, 13)

# %%
ds_oct22016_all.drop(ds_oct22016_all.columns[[6,7,9,10,11]], axis=1, inplace=True)
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ds_nov2016_all.drop(ds_nov2016_all.columns[[6,7,9,10,11]], axis=1, inplace=True)
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ds_oct22016_all.shape
# Out:
# (981350, 8)

# %%
ds_nov2016_all.shape
# Out:
# (2540144, 8)

# %%
ds2 = ds_jun2016_all.append(ds_oct22016_all)

# %%
ds_jun2016_all.shape
# Out:
# (10280282, 8)

# %%
ds2.shape
# Out:
# (11261632, 8)

# %%
ds = ds2.append(ds_nov2016_all)

# %%
ds.shape
# Out:
# (13801776, 8)

# %%
2540144+981350+10280282
# Out:
# 13801776

# %%
ds.to_csv("ds_june_to_nov.csv")

# %%
ds_nov2016_all.head()
# Out:
#                       ds_clust                            ds_name  ds_cap_gb  \
# 29389602  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 29389603  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 29389604  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 29389605  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
# 29389606  ASH02NA15-CL5-PRODDB  ASH02-5600-01-CL5HP_RG0001_511_OS      99.75
#
#           ds_free_space   ds_storagetier ds_storagetype     ds_loc  \
# 29389602      56.038086  HIGHPERFORMANCE           VMFS  ash02na15
# 29389603      56.038086  HIGHPERFORMANCE           VMFS  ash02na15
# 29389604      56.038086  HIGHPERFORMANCE           VMFS  ash02na15
# 29389605      56.038086  HIGHPERFORMANCE           VMFS  ash02na15
# 29389606      56.038086  HIGHPERFORMANCE           VMFS  ash02na15
#
#                         Date
# 29389602 2016-11-01 08:03:19
# 29389603 2016-11-01 10:03:18
# ...

# %%
ds.dtypes
# Out:
# ds_clust                  object
# ds_name                   object
# ds_cap_gb                float64
# ds_free_space            float64
# ds_storagetier            object
# ds_storagetype            object
# ds_loc                    object
# Date              datetime64[ns]
# dtype: object
